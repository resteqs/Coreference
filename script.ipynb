# %%
import os
import numpy as np
import re
import pandas as pd
import argparse
import subprocess
import tempfile
import shutil
import whisper
from pydub import AudioSegment
from tqdm import tqdm
import csv
import time

# %%
def clean_text(text):
    """Remove symbols and special characters from text."""
    # Remove punctuation and special characters but keep alphanumeric and spaces and apostrophs
    return re.sub(r'[^a-zA-Z0-9\s\']', '', text)
    #return text

def convert_conll_to_txt(conll_file, txt_file):
    """Convert CoNLL file to cleaned text file."""
    # Now accepts file paths instead of directories
    words = []
    
    with open(conll_file, 'r', encoding='utf-8') as f_in:
        for line in f_in:
            if line.strip():  # Non-empty line
                tokens = line.strip().split()
                if len(tokens) > 3:  # Ensure enough columns
                    word = clean_text(tokens[3])  # Clean the word
                    if word:  # Only add non-empty words
                        words.append(word)
            else:
                # Add sentence boundary
                if words:
                    words.append('\n')
    
    # Write cleaned text to output file
    with open(txt_file, 'w', encoding='utf-8') as f_out:
        f_out.write(' '.join(words))

# %%
def run_mfa_align(input_dir, output_dir):
    # Ensure directories exist
    if not os.path.exists(input_dir):
        print(f"Input directory does not exist: {input_dir}")
        return
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the MFA command
    command = [
        'mfa', 'align',
        input_dir,
        'english_mfa',  # Specify the pronunciation dictionary
        'english_mfa',  # Specify the acoustic model
        output_dir
    ]

    try:
        subprocess.run(command, check=True)
        print("Alignment completed successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error during alignment: {e}")
    except PermissionError as e:
        print(f"Permission error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
def read_textgrid_intervals(textgrid_path):
    #Extract intervaals with words and their timestamps.
    word_intervals = []
    with open(textgrid_path, 'r') as file:
        lines = file.readlines()
    
    is_word_tier = False
    for i, line in enumerate(lines):
        if 'name = "words"' in line:
            is_word_tier = True
            continue
        
        # Extract interval data within the words tier with some regex magic
        if is_word_tier:
            if 'xmin' in line:
                xmin = float(re.search(r"[-+]?\d*\.\d+|\d+", line).group())
            elif 'xmax' in line:
                xmax = float(re.search(r"[-+]?\d*\.\d+|\d+", line).group())
            elif 'text' in line:
                text_match = re.search(r'text = "(.*)"', line)
                text = text_match.group(1).strip() if text_match else ""
                
                # We skip empty text
                if text:
                    word_intervals.append({
                        "word": text,
                        "start_time": xmin,
                        "end_time": xmax
                    })
            
            if 'name' in line and 'name = ' in line and not 'name = "words"' in line:
                break
    
    return word_intervals

# %%
def verify_mfa_alignment(audio_file, textgrid_intervals, output_csv):
    """Verify MFA alignment using Whisper and output results to a CSV file."""
    # Load Whisper model
    print("Loading Whisper model...")
    model = whisper.load_model("tiny")
    
    # Load audio file
    print(f"Loading audio file: {audio_file}")
    audio = AudioSegment.from_wav(audio_file)
    
    total_words = len(textgrid_intervals)
    start_time = time.time()
    
    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)
        # Write header
        csv_writer.writerow(['Correct Word', 'Whisper Prediction', 'Match', 'Start Time', 'End Time', 'Execution Time'])
        
        for index, interval in enumerate(textgrid_intervals, 1):
            word = interval["word"]
            if not word or word.isspace():
                continue
                
            # Extract time segment
            start_ms = int(interval["start_time"] * 1000)
            end_ms = int(interval["end_time"] * 1000)
            segment = audio[start_ms:end_ms]
            
            # Process segment
            temp_file = "temp_segment.wav"
            segment.export(temp_file, format="wav")
            
            # Get Whisper transcription
            result = model.transcribe(temp_file)
            whisper_text = result["text"].strip().lower()
            
            # Compare results
            mfa_word = word.lower().strip()
            is_match = 1 if mfa_word == whisper_text else 0
            
            exec_time = time.time() - start_time
            
            # Write to CSV
            csv_writer.writerow([
                mfa_word,
                whisper_text,
                is_match,
                f"{interval['start_time']:.2f}",
                f"{interval['end_time']:.2f}",
                f"{exec_time:.2f}"
            ])
            
            # Remove temp file
            os.remove(temp_file)
            
            # Print progress
            progress = (index / total_words) * 100
            print(f"{index}/{total_words} ; {progress:.2f}%")

# %% [markdown]
# Aligns words from the CoNLL file with words from the TextGrid intervals using the *Needleman-Wunsch* algorithm.
#
#     Steps:
#     1. **Initialization:**
#        - Create a scoring matrix (`score_matrix`) of size (n+1) x (m+1), where n is the length of `conll_words` and m is the length of `textgrid_words`.
#        - Initialize the first row and column with cumulative gap penalties to represent alignments with leading gaps.
#
#     2. **Scoring Matrix Construction:**
#        - Iterate over each cell in the matrix to compute the optimal score based on:
#          - **Match:** If the current words from `conll_words` and `textgrid_words` match, add a positive `match_score`.
#          - **Mismatch:** If the words do not match, add a negative `mismatch_penalty`.
#          - **Insertion/Deletion (Gaps):** Assign a negative `gap_penalty` for insertions or deletions.
#        - Calculate scores for:
#          - **Diagonal move (match/mismatch):** `score_matrix[i-1][j-1] + score`
#          - **Up move (deletion in TextGrid):** `score_matrix[i-1][j] + gap_penalty`
#          - **Left move (insertion in TextGrid):** `score_matrix[i][j-1] + gap_penalty`
#        - Select the move with the highest score and store it in `score_matrix[i][j]`.
#        - Record the move direction in the `traceback_matrix` for later path reconstruction.
#
#     3. **Traceback:**
#        - Start from the bottom-right cell of the matrices (`score_matrix[n][m]`).
#        - Reconstruct the optimal alignment by moving in the direction indicated by `traceback_matrix`:
#          - **'diag':** Align the current words from both sequences.
#          - **'up':** Align the word from `conll_words` with a gap (deletion in `textgrid_words`).
#          - **'left':** Align a gap with the word from `textgrid_words` (insertion in `conll_words`).
#        - Continue tracing back until reaching the top-left cell.
#
#     4. **Results:**
#        - Obtain `aligned_conll` and `aligned_textgrid`, which are the aligned sequences including gaps ('-') where necessary.
#        - Collect corresponding time intervals from `textgrid_intervals` for aligned words.
#        - Reverse the aligned sequences and times to obtain the correct order.
#
#     Parameters:
#         conll_words (list): List of words extracted from the CoNLL file.
#         textgrid_intervals (list): List of dictionaries from the TextGrid file, each containing:
#                                    - "word": The word string.
#                                    - "start_time": Start time of the interval.
#                                    - "end_time": End time of the interval.
#
#     Returns:
#         aligned_conll (list): Aligned words from the CoNLL file, including gaps.
#         aligned_textgrid (list): Aligned words from the TextGrid intervals, including gaps.
#         aligned_times (list): List of (start_time, end_time) tuples corresponding to `aligned_textgrid`.

# %%
def align_sequences(conll_words, textgrid_intervals): #Using the Needleman-Wunsch algortihm for alligning sequences, as the files don't fit perfectly
       

    # lets get Textgrid words and tinestamps
    textgrid_words = [str(interval["word"]) for interval in textgrid_intervals]
    textgrid_times = [(interval["start_time"], interval["end_time"]) for interval in textgrid_intervals]

    # Initialize scoring parameters
    match_score = 2
    mismatch_penalty = -1
    gap_penalty = -2

    n = len(conll_words)
    m = len(textgrid_words)

    # Initialize the scoring matrix
    score_matrix = np.zeros((n + 1, m + 1))
    traceback_matrix = np.zeros((n + 1, m + 1), dtype='object')

    # Initialize first row and column
    for i in range(1, n + 1):
        score_matrix[i][0] = gap_penalty * i
        traceback_matrix[i][0] = 'up'  # Deletion
    for j in range(1, m + 1):
        score_matrix[0][j] = gap_penalty * j
        traceback_matrix[0][j] = 'left'  # Insertion

    # Fill in the scoring matrix
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            word1 = conll_words[i - 1].lower()
            word2 = textgrid_words[j - 1].lower()

            if word1 == word2:
                score = match_score
            else:
                score = mismatch_penalty

            diag_score = score_matrix[i - 1][j - 1] + score  # Match/Mismatch
            up_score = score_matrix[i - 1][j] + gap_penalty   # Deletion
            left_score = score_matrix[i][j - 1] + gap_penalty # Insertion

            max_score = max(diag_score, up_score, left_score)
            score_matrix[i][j] = max_score

            # Traceback pointers
            if max_score == diag_score:
                traceback_matrix[i][j] = 'diag'
            elif max_score == up_score:
                traceback_matrix[i][j] = 'up'
            else:
                traceback_matrix[i][j] = 'left'

    # Traceback to get the alignment
    aligned_conll = []
    aligned_textgrid = []
    aligned_times = []
    i, j = n, m

    while i > 0 or j > 0:
        direction = traceback_matrix[i][j]

        if direction == 'diag':
            aligned_conll.append(conll_words[i - 1])
            aligned_textgrid.append(textgrid_words[j - 1])
            aligned_times.append(textgrid_times[j - 1])
            i -= 1
            j -= 1
        elif direction == 'up':
            aligned_conll.append(conll_words[i - 1])
            aligned_textgrid.append('-')  # Gap in TextGrid
            aligned_times.append((None, None))
            i -= 1
        else:  # 'left'
            aligned_conll.append('-')  # Gap in CoNLL
            aligned_textgrid.append(textgrid_words[j - 1])
            aligned_times.append(textgrid_times[j - 1])
            j -= 1

    # Reverse the aligned sequences
    aligned_conll = aligned_conll[::-1]
    aligned_textgrid = aligned_textgrid[::-1]
    aligned_times = aligned_times[::-1]

    return aligned_conll, aligned_textgrid, aligned_times

# %%
def add_timestamps_to_conll(conll_path, textgrid_intervals, output_path):
    """Adds timestamps from TextGrid intervals to the CoNLL file using sequence alignment."""
    import pandas as pd

    # Define column names matching your CoNLL file structure
    column_names = ['col0', 'col1', 'col2', 'word', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9', 'col10', 'col11', "col12"]

    # Read the CoNLL file using the adjusted column names
    conll_data = pd.read_csv(
        conll_path,
        sep="\t",
        header=None,
        names=column_names,
        skip_blank_lines=True,
    )

    # Extract the 'word' column
    conll_words = conll_data['word'].astype(str).tolist()

    # Rest of your code remains the same...
    # Align sequences using the conll_words
    aligned_conll, aligned_textgrid, aligned_times = align_sequences(conll_words, textgrid_intervals)

    # Prepare the output data
    start_times = []
    end_times = []
    for conll_word, times in zip(aligned_conll, aligned_times):
        if conll_word != '-':
            start_times.append(times[0])  # May be None
            end_times.append(times[1])    # May be None

    # Add the times to the DataFrame
    conll_data = conll_data.loc[conll_data['word'] != '-'].reset_index(drop=True)
    conll_data['start_time'] = start_times
    conll_data['end_time'] = end_times

    # Save the updated data to the output file
    conll_data.to_csv(output_path, sep="\t", index=False, header=False)

    # Optionally, print or log any mismatches or alignments
    for idx, (c_word, tg_word) in enumerate(zip(aligned_conll, aligned_textgrid)):
        if c_word != tg_word and c_word != '-' and tg_word != '-':
            print(f"Mismatch at position {idx}: CoNLL word '{c_word}' vs. TextGrid word '{tg_word}'")
        elif c_word == '-' or tg_word == '-':
            print(f"Insertion/Deletion at position {idx}: CoNLL word '{c_word}' vs. TextGrid word '{tg_word}'")

# %%
def process_files(input_dir, output_dir=None):
    """Process audio and CoNLL files to create aligned output."""
    # Normalize and validate paths
    input_dir = os.path.abspath(input_dir)
    output_dir = os.path.abspath(output_dir) if output_dir else input_dir

    # Validate input directory
    if not os.path.isdir(input_dir):
        raise ValueError(f"Input directory does not exist: {input_dir}")

    # Find CoNLL file
    conll_files = [f for f in os.listdir(input_dir) if f.endswith('.conll')]
    if not conll_files:
        raise FileNotFoundError("No .conll file found in input directory")
    
    # Get base name and construct file paths
    base_name = os.path.splitext(conll_files[0])[0]
    
    # Construct file paths using absolute paths
    conll_file = os.path.join(input_dir, conll_files[0])
    audio_file = os.path.join(input_dir, f"{base_name}.wav")
    txt_file = os.path.join(output_dir, f"{base_name}.txt")
    textgrid_file = os.path.join(output_dir, f"{base_name}.TextGrid")
    output_conll = os.path.join(output_dir, f"{base_name}_time.conll")

    # Validate input files exist
    if not os.path.isfile(audio_file):
        raise FileNotFoundError(f"Audio file not found: {audio_file}")
    if not os.path.isfile(conll_file):
        raise FileNotFoundError(f"CoNLL file not found: {conll_file}")

    # Create output directory
    os.makedirs(output_dir, exist_ok=True)

    # Convert CoNLL to txt
    convert_conll_to_txt(conll_file, txt_file)
    
    # Run MFA align with directory containing audio and txt
    success = run_mfa_align(input_dir, output_dir)
    

    # Process TextGrid and create time-aligned CoNLL
    if not os.path.isfile(textgrid_file):
        raise FileNotFoundError(f"TextGrid file not created: {textgrid_file}")
        
    intervals = read_textgrid_intervals(textgrid_file)
    output_csv = os.path.join(output_dir, 'whisper_analysis.csv')
    verify_mfa_alignment(audio_file, intervals, output_csv)
    add_timestamps_to_conll(conll_file, intervals, output_conll)

    print(f"Processing completed. Output files saved in: {output_dir}")

# %%
#Handles execution in .ipynb files
def process_with_args(input_dir: str, output_dir: str = ""):
    """Process files with given arguments."""
    try:
        process_files(input_dir, output_dir)
        print(f"Successfully processed files in {input_dir}")
    except Exception as e:
        print(f"Error processing files: {e}")

# %%
# Run to execute the code :))
# Step 1: Performs file check (check for .conll file and .wav file in input_dir)
# Step 2: Creates a txt from conll (creates in defualt: input_dir if no output_dir given)
# Step 2a: Reduces text to alphanumerics, appostrophs (') and single whitespaces
# Step 3: Runs the MFA alligner (creates .TextGrid file in same dir as above)
# Step 4: Creates a working copy for .conll (name_time.conll)
# Step 5: Reads the intervalls from .TextGrid
# Step 6: Performs a cross-check using whisper
# Step 7: Match timestamps from TextGrid to _time.conll using Needleman-Wunsch algorithm
# Step 6: Enjoy :)

input_dir = "C:/Users/manto/Documents/Coreference-project-NLP/test3"
output_dir = ""
process_with_args(input_dir, output_dir)
# Out:
# Alignment completed successfully.
# Mismatch at position 0: CoNLL word 'nan' vs. TextGrid word 'part'
# Mismatch at position 1: CoNLL word 'CHAPTER' vs. TextGrid word 'chapter'
# Insertion/Deletion at position 3: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 4: CoNLL word 'A' vs. TextGrid word 'a'
# Mismatch at position 5: CoNLL word 'Not' vs. TextGrid word 'not'
# Mismatch at position 6: CoNLL word 'Unnatural' vs. TextGrid word 'unnatural'
# Mismatch at position 7: CoNLL word 'Enterprise' vs. TextGrid word 'enterprise'
# Mismatch at position 8: CoNLL word 'This' vs. TextGrid word 'this'
# Insertion/Deletion at position 13: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 15: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 16: CoNLL word 'If' vs. TextGrid word 'if'
# Mismatch at position 17: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 25: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 29: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 37: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 38: CoNLL word 'Whole' vs. TextGrid word 'whole'
# Insertion/Deletion at position 43: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 47: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 50: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 54: CoNLL word '--' vs. TextGrid word '-'
# Mismatch at position 56: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 60: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 61: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 65: CoNLL word '’s' vs. TextGrid word '-'
# Insertion/Deletion at position 66: CoNLL word '-' vs. TextGrid word 's'
# Insertion/Deletion at position 73: CoNLL word ';' vs. TextGrid word '-'
# Insertion/Deletion at position 81: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 84: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 88: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 95: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 97: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 102: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 107: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 108: CoNLL word 'Nobody' vs. TextGrid word 'nobody'
# Insertion/Deletion at position 115: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 116: CoNLL word 'Descriptions' vs. TextGrid word 'descriptions'
# Mismatch at position 118: CoNLL word 'n’t' vs. TextGrid word 'nt'
# Insertion/Deletion at position 126: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 128: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 135: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 136: CoNLL word 'But' vs. TextGrid word 'but'
# Mismatch at position 138: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 144: CoNLL word ';' vs. TextGrid word '-'
# Insertion/Deletion at position 156: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 157: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 159: CoNLL word 'n’t' vs. TextGrid word 'nt'
# Mismatch at position 167: CoNLL word 'self-appointed' vs. TextGrid word 'selfappointed'
# Insertion/Deletion at position 169: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 172: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 174: CoNLL word 'land-greedy' vs. TextGrid word 'landgreedy'
# Insertion/Deletion at position 176: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 185: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 186: CoNLL word 'They' vs. TextGrid word 'they'
# Insertion/Deletion at position 191: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 192: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 197: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 210: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 211: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 215: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 216: CoNLL word 'There' vs. TextGrid word 'there'
# Insertion/Deletion at position 221: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 225: CoNLL word '--' vs. TextGrid word '-'
# Mismatch at position 226: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Mismatch at position 227: CoNLL word 'O.' vs. TextGrid word 'o'
# Mismatch at position 228: CoNLL word 'Nicholson' vs. TextGrid word 'nicholson'
# Insertion/Deletion at position 229: CoNLL word '(' vs. TextGrid word '-'
# Mismatch at position 236: CoNLL word 'Old' vs. TextGrid word 'old'
# Mismatch at position 237: CoNLL word 'Nick' vs. TextGrid word 'nick'
# Insertion/Deletion at position 238: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 242: CoNLL word ')' vs. TextGrid word '-'
# Insertion/Deletion at position 243: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 244: CoNLL word 'Jeff' vs. TextGrid word 'jeff'
# Mismatch at position 245: CoNLL word 'Margrave' vs. TextGrid word 'margrave'
# Insertion/Deletion at position 246: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 248: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 249: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 250: CoNLL word 'Vandyck' vs. TextGrid word 'vandyck'
# Mismatch at position 251: CoNLL word 'Jennings' vs. TextGrid word 'jennings'
# Insertion/Deletion at position 252: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 253: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 261: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 275: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 276: CoNLL word 'All' vs. TextGrid word 'all'
# Insertion/Deletion at position 283: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 284: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 293: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 294: CoNLL word 'His' vs. TextGrid word 'his'
# Insertion/Deletion at position 299: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 300: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 317: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 323: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 326: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 327: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 332: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 339: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 345: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 346: CoNLL word 'Had' vs. TextGrid word 'had'
# Insertion/Deletion at position 353: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 363: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 364: CoNLL word 'We' vs. TextGrid word 'we'
# Mismatch at position 374: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 375: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 376: CoNLL word 'Jeff' vs. TextGrid word 'jeff'
# Mismatch at position 377: CoNLL word 'Margrave' vs. TextGrid word 'margrave'
# Insertion/Deletion at position 384: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 387: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 390: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 401: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 402: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 407: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 411: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 423: CoNLL word '“' vs. TextGrid word '-'
# Insertion/Deletion at position 428: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 429: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 430: CoNLL word 'As' vs. TextGrid word 'as'
# Insertion/Deletion at position 433: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 435: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 438: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 439: CoNLL word 'You' vs. TextGrid word 'you'
# Insertion/Deletion at position 451: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 454: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 455: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 456: CoNLL word '’m' vs. TextGrid word 'm'
# Insertion/Deletion at position 461: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 462: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 467: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 473: CoNLL word ';' vs. TextGrid word '-'
# Mismatch at position 474: CoNLL word 'Jeff' vs. TextGrid word 'jeff'
# Insertion/Deletion at position 482: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 484: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 486: CoNLL word 'n’t' vs. TextGrid word 'nt'
# Insertion/Deletion at position 494: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 503: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 505: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 506: CoNLL word 'There' vs. TextGrid word 'there'
# Insertion/Deletion at position 512: CoNLL word 'n’t' vs. TextGrid word '-'
# Mismatch at position 513: CoNLL word '.' vs. TextGrid word 'nt'
# Mismatch at position 514: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 525: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 526: CoNLL word 'They' vs. TextGrid word 'they'
# Insertion/Deletion at position 530: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 534: CoNLL word 'Jeff' vs. TextGrid word 'jeff'
# Insertion/Deletion at position 543: CoNLL word ';' vs. TextGrid word '-'
# Mismatch at position 546: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Mismatch at position 547: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 549: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 552: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 556: CoNLL word ';' vs. TextGrid word '-'
# Insertion/Deletion at position 561: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 562: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 566: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Mismatch at position 567: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 569: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 570: CoNLL word 'The' vs. TextGrid word 'the'
# Insertion/Deletion at position 585: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 594: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 598: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 608: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 609: CoNLL word 'But' vs. TextGrid word 'but'
# Insertion/Deletion at position 617: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 618: CoNLL word 'That' vs. TextGrid word 'that'
# Insertion/Deletion at position 626: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 627: CoNLL word 'My' vs. TextGrid word 'my'
# Insertion/Deletion at position 637: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 638: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 639: CoNLL word '’m' vs. TextGrid word 'm'
# Insertion/Deletion at position 643: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 648: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 654: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 655: CoNLL word 'What' vs. TextGrid word 'what'
# Insertion/Deletion at position 667: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 668: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 682: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 683: CoNLL word 'And' vs. TextGrid word 'and'
# Insertion/Deletion at position 691: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 698: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 700: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 702: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 706: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 722: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 723: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 740: CoNLL word 'Woman' vs. TextGrid word 'woman'
# Mismatch at position 741: CoNLL word 'Land' vs. TextGrid word 'land'
# Insertion/Deletion at position 746: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 747: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 748: CoNLL word 'Up' vs. TextGrid word 'up'
# Insertion/Deletion at position 750: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 751: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 752: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 753: CoNLL word 'Over' vs. TextGrid word 'over'
# Insertion/Deletion at position 755: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 756: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 757: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 758: CoNLL word 'Way' vs. TextGrid word 'way'
# Insertion/Deletion at position 760: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 761: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 769: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 779: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 790: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 796: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 797: CoNLL word 'nan' vs. TextGrid word 'none'
# Insertion/Deletion at position 804: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 805: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 808: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 810: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 813: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 820: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 821: CoNLL word 'But' vs. TextGrid word 'but'
# Insertion/Deletion at position 828: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 836: CoNLL word '--' vs. TextGrid word '-'
# Mismatch at position 838: CoNLL word 'Big' vs. TextGrid word 'big'
# Mismatch at position 839: CoNLL word 'Country' vs. TextGrid word 'country'
# Insertion/Deletion at position 840: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 841: CoNLL word 'Big' vs. TextGrid word 'big'
# Mismatch at position 842: CoNLL word 'Houses' vs. TextGrid word 'houses'
# Insertion/Deletion at position 843: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 844: CoNLL word 'Plenty' vs. TextGrid word 'plenty'
# Mismatch at position 845: CoNLL word 'People' vs. TextGrid word 'people'
# Insertion/Deletion at position 846: CoNLL word '--' vs. TextGrid word '-'
# Mismatch at position 847: CoNLL word 'All' vs. TextGrid word 'all'
# Mismatch at position 848: CoNLL word 'Women' vs. TextGrid word 'women'
# Insertion/Deletion at position 849: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 850: CoNLL word 'Had' vs. TextGrid word 'had'
# Insertion/Deletion at position 855: CoNLL word '?' vs. TextGrid word '-'
# Mismatch at position 856: CoNLL word 'Yes' vs. TextGrid word 'yes'
# Insertion/Deletion at position 857: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 861: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 867: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 868: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 874: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 880: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 881: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 888: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 894: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 895: CoNLL word 'Naturally' vs. TextGrid word 'naturally'
# Mismatch at position 896: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 899: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 900: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 910: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 911: CoNLL word 'But' vs. TextGrid word 'but'
# Insertion/Deletion at position 919: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 935: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 944: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 950: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 951: CoNLL word 'The' vs. TextGrid word 'the'
# Insertion/Deletion at position 966: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 975: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 976: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 989: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 993: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 994: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1005: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1012: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1015: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1016: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 1024: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1025: CoNLL word '“' vs. TextGrid word '-'
# Insertion/Deletion at position 1028: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1031: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1034: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1038: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1039: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1040: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 1050: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1053: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 1055: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 1063: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1065: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1069: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1070: CoNLL word 'Yes' vs. TextGrid word 'yes'
# Insertion/Deletion at position 1071: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1077: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1083: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1084: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1085: CoNLL word 'River' vs. TextGrid word 'river'
# Insertion/Deletion at position 1086: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1089: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1093: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1094: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1095: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Mismatch at position 1104: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1106: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1107: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1108: CoNLL word 'What' vs. TextGrid word 'what'
# Insertion/Deletion at position 1112: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 1113: CoNLL word 'Van' vs. TextGrid word 'van'
# Insertion/Deletion at position 1114: CoNLL word '?' vs. TextGrid word '-'
# Insertion/Deletion at position 1115: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1116: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1119: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1120: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1125: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1126: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1127: CoNLL word 'Ask' vs. TextGrid word 'ask'
# Insertion/Deletion at position 1133: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1134: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1135: CoNLL word 'The' vs. TextGrid word 'the'
# Insertion/Deletion at position 1141: CoNLL word ';' vs. TextGrid word '-'
# Mismatch at position 1142: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1147: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1150: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1151: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1152: CoNLL word 'Let' vs. TextGrid word 'let'
# Mismatch at position 1153: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1155: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1156: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1158: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1159: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1160: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1161: CoNLL word 'Just' vs. TextGrid word 'just'
# Insertion/Deletion at position 1164: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1165: CoNLL word 'Maybe' vs. TextGrid word 'maybe'
# Insertion/Deletion at position 1171: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1172: CoNLL word 'May' vs. TextGrid word 'may'
# Insertion/Deletion at position 1177: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1178: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 1179: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1180: CoNLL word 'May' vs. TextGrid word 'may'
# Insertion/Deletion at position 1183: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1184: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1185: CoNLL word 'Jeff' vs. TextGrid word 'jeff'
# Insertion/Deletion at position 1187: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1192: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1193: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 1197: CoNLL word ';' vs. TextGrid word '-'
# Insertion/Deletion at position 1202: CoNLL word ';' vs. TextGrid word '-'
# Mismatch at position 1208: CoNLL word '’d' vs. TextGrid word 'd'
# Insertion/Deletion at position 1213: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1218: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1229: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1242: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1243: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 1249: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1252: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1253: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1264: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1265: CoNLL word 'There' vs. TextGrid word 'there'
# Insertion/Deletion at position 1287: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1288: CoNLL word 'But' vs. TextGrid word 'but'
# Insertion/Deletion at position 1292: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 1294: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 1297: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1298: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1303: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1311: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1312: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 1323: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1326: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1339: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1340: CoNLL word 'Our' vs. TextGrid word 'our'
# Insertion/Deletion at position 1353: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1355: CoNLL word '“' vs. TextGrid word '-'
# Insertion/Deletion at position 1358: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1361: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1362: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1363: CoNLL word 'This' vs. TextGrid word 'this'
# Insertion/Deletion at position 1373: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1383: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1384: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 1393: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1401: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1418: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1424: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1428: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1429: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1430: CoNLL word 'One' vs. TextGrid word 'one'
# Insertion/Deletion at position 1436: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1437: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1438: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1441: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1442: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1443: CoNLL word 'May' vs. TextGrid word 'may'
# Insertion/Deletion at position 1451: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1452: CoNLL word 'They' vs. TextGrid word 'they'
# Insertion/Deletion at position 1457: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1458: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1459: CoNLL word 'Suddenly' vs. TextGrid word 'suddenly'
# Insertion/Deletion at position 1470: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1471: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 1479: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1488: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1489: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 1492: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1493: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 1513: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1514: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 1518: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1519: CoNLL word 'The' vs. TextGrid word 'the'
# Insertion/Deletion at position 1527: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1528: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1529: CoNLL word 'That' vs. TextGrid word 'that'
# Mismatch at position 1530: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1533: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1534: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1535: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1537: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1538: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1539: CoNLL word 'Must' vs. TextGrid word 'must'
# Insertion/Deletion at position 1547: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1548: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1549: CoNLL word 'But' vs. TextGrid word 'but'
# Insertion/Deletion at position 1556: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1562: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1563: CoNLL word 'The' vs. TextGrid word 'the'
# Insertion/Deletion at position 1570: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1571: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 1592: CoNLL word ';' vs. TextGrid word '-'
# Insertion/Deletion at position 1594: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1598: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1599: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1610: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1611: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1612: CoNLL word 'Chemicals' vs. TextGrid word 'chemicals'
# Insertion/Deletion at position 1616: CoNLL word '--' vs. TextGrid word '-'
# Mismatch at position 1617: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 1619: CoNLL word 'n’t' vs. TextGrid word 'nt'
# Insertion/Deletion at position 1624: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1625: CoNLL word 'Look' vs. TextGrid word 'look'
# Insertion/Deletion at position 1630: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1631: CoNLL word 'Let' vs. TextGrid word 'let'
# Mismatch at position 1632: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1635: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1636: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 1639: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1640: CoNLL word '“' vs. TextGrid word '-'
# Insertion/Deletion at position 1646: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1647: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1648: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 1668: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1669: CoNLL word 'Here' vs. TextGrid word 'here'
# Insertion/Deletion at position 1681: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1682: CoNLL word 'More' vs. TextGrid word 'more'
# Insertion/Deletion at position 1683: CoNLL word '--' vs. TextGrid word '-'
# Mismatch at position 1684: CoNLL word 'Jeff' vs. TextGrid word 'jeff'
# Mismatch at position 1689: CoNLL word 'unlooked-for' vs. TextGrid word 'unlookedfor'
# Insertion/Deletion at position 1691: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1692: CoNLL word 'It' vs. TextGrid word 'it'
# Insertion/Deletion at position 1697: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1700: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1705: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1706: CoNLL word 'But' vs. TextGrid word 'but'
# Mismatch at position 1710: CoNLL word 'well-woven' vs. TextGrid word 'wellwoven'
# Insertion/Deletion at position 1712: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1716: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1728: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1729: CoNLL word 'No' vs. TextGrid word 'no'
# Insertion/Deletion at position 1740: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1741: CoNLL word 'The' vs. TextGrid word 'the'
# Insertion/Deletion at position 1748: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1754: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1755: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1756: CoNLL word 'One' vs. TextGrid word 'one'
# Insertion/Deletion at position 1759: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1763: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1767: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1768: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 1772: CoNLL word ',' vs. TextGrid word '-'
# Mismatch at position 1781: CoNLL word 'bright-hued' vs. TextGrid word 'brighthued'
# Insertion/Deletion at position 1783: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1784: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1785: CoNLL word 'Come' vs. TextGrid word 'come'
# Insertion/Deletion at position 1787: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1788: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 1791: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1796: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1797: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1798: CoNLL word 'Woman' vs. TextGrid word 'woman'
# Mismatch at position 1799: CoNLL word 'Country' vs. TextGrid word 'country'
# Insertion/Deletion at position 1800: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1803: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1804: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1805: CoNLL word 'Then' vs. TextGrid word 'then'
# Insertion/Deletion at position 1809: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1810: CoNLL word 'We' vs. TextGrid word 'we'
# Insertion/Deletion at position 1825: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1826: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 1835: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1840: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1843: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1845: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1849: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1850: CoNLL word 'No' vs. TextGrid word 'no'
# Insertion/Deletion at position 1854: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1856: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1857: CoNLL word 'Some' vs. TextGrid word 'some'
# Insertion/Deletion at position 1862: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1867: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1868: CoNLL word 'I' vs. TextGrid word 'i'
# Mismatch at position 1871: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Mismatch at position 1872: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1877: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1878: CoNLL word 'No' vs. TextGrid word 'no'
# Insertion/Deletion at position 1882: CoNLL word '?' vs. TextGrid word '-'
# Mismatch at position 1883: CoNLL word 'Dangerous' vs. TextGrid word 'dangerous'
# Insertion/Deletion at position 1884: CoNLL word '?' vs. TextGrid word '-'
# Mismatch at position 1885: CoNLL word 'He' vs. TextGrid word 'he'
# Insertion/Deletion at position 1898: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1899: CoNLL word 'But' vs. TextGrid word 'but'
# Insertion/Deletion at position 1908: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1922: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1934: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1935: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1936: CoNLL word 'They' vs. TextGrid word 'they'
# Insertion/Deletion at position 1943: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1944: CoNLL word '”' vs. TextGrid word '-'
# Mismatch at position 1945: CoNLL word 'I' vs. TextGrid word 'i'
# Insertion/Deletion at position 1947: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1948: CoNLL word 'But' vs. TextGrid word 'but'
# Mismatch at position 1949: CoNLL word 'Terry' vs. TextGrid word 'terry'
# Insertion/Deletion at position 1954: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1955: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1956: CoNLL word 'Look' vs. TextGrid word 'look'
# Insertion/Deletion at position 1958: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1960: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1961: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 1964: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 1965: CoNLL word '“' vs. TextGrid word '-'
# Mismatch at position 1966: CoNLL word 'This' vs. TextGrid word 'this'
# Insertion/Deletion at position 1970: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1971: CoNLL word 'Let' vs. TextGrid word 'let'
# Mismatch at position 1972: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1979: CoNLL word '.' vs. TextGrid word '-'
# Mismatch at position 1980: CoNLL word 'Let' vs. TextGrid word 'let'
# Mismatch at position 1981: CoNLL word '’s' vs. TextGrid word 's'
# Insertion/Deletion at position 1986: CoNLL word '‘' vs. TextGrid word '-'
# Insertion/Deletion at position 1988: CoNLL word ',' vs. TextGrid word '-'
# Insertion/Deletion at position 1993: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 1996: CoNLL word '--' vs. TextGrid word '-'
# Insertion/Deletion at position 2004: CoNLL word '.' vs. TextGrid word '-'
# Insertion/Deletion at position 2005: CoNLL word '”' vs. TextGrid word '-'
# Insertion/Deletion at position 2006: CoNLL word 'nan' vs. TextGrid word '-'
# Processing completed. Output files saved in: C:\Users\manto\Documents\Coreference-project-NLP\test3
# Successfully processed files in C:/Users/manto/Documents/Coreference-project-NLP/test3
